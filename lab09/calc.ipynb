# %%
from cProfile import label
import matplotlib.pyplot as plt
import csv
import numpy as np
import pandas as pd
from sympy import *
import scipy as sp
import sys
sys.path.append('..')

from libka import *

# %%
df = pd.read_csv("in/data.csv", names = ["lam",  "flux", "U", "przel"], header = 0)

# %%
df["U"] = df["U"] / df["przel"]
df["U/flux"] = df["U"]/df["flux"]

# %%
df
# Out:
#      lam      flux             U  przel        U/flux
# 0   0.45   0.04100  8.270000e-06   1000  2.017073e-04
# 1   0.46   0.05411  1.062000e-05   1000  1.962669e-04
# 2   0.47   0.06840  1.361000e-05   1000  1.989766e-04
# 3   0.48   0.08500  1.701000e-05   1000  2.001176e-04
# 4   0.49   0.10600  2.150000e-05   1000  2.028302e-04
# 5   0.50   0.13000  2.663000e-05   1000  2.048462e-04
# 6   0.51   0.15900  3.254000e-05   1000  2.046541e-04
# 7   0.52   0.19200  3.983000e-05   1000  2.074479e-04
# 8   0.54   0.26800  5.750000e-05   1000  2.145522e-04
# 9   0.56   0.37000  7.967000e-05   1000  2.153243e-04
# 10  0.58   0.48000  1.076300e-04   1000  2.242292e-04
# 11  0.60   0.66000  1.406400e-04   1000  2.130909e-04
# 12  0.62   0.77500  1.798600e-04   1000  2.320774e-04
# 13  0.64   0.95500  2.225000e-01      1  2.329843e-01
# 14  0.66   1.16000  2.705000e-01      1  2.331897e-01
# 15  0.68   1.42000  3.244000e-01      1  2.284507e-01
# ...
